# %% [markdown]
# # Note : NOT TESTED (coz' no data)

# %% [markdown]
# ## Get and clean data

# %%
from data_getter import get_3d_data, get_2d_data

coords_3d_frames = get_3d_data()
coords_2d_frames = get_2d_data()
# data format : image_list containing articulation_list which are vertical vectors of height 2 or 3 (for respectively 2d data and 3d data)


# get data
# get one to one fit for 2d and 3d data
# get only similar points (wrist, elbows, soulders)

# %%
len(coords_3d_frames)
# Out:
# 105

# %% [markdown]
# ## Greedy Algo Try

# %% [markdown]
# ### Evaluation function

# %%
def get_mean_distance(projection_mat, offset_mat, debug=True) :
    total_dist = []
    for frame_3d, frame_2d in zip(coords_3d_frames, coords_2d_frames) :
        for articulation_3d, articulation_2d in zip(frame_3d, frame_2d) :
            x_truth, y_truth = articulation_2d
            if x_truth == 0 and y_truth == 0 : continue # bad acquisition; so we skip these numbers
            x_projection, y_projection = np.add(projection_mat.dot(articulation_3d), offset_mat)
            dist = sqrt((x_truth-x_projection)**2 + (y_truth-y_projection)**2)
            total_dist.append(dist)
    mean_dist = sum(total_dist) / len(total_dist)
    return mean_dist

def step_asservissment(mean_dist, prev_mse) :
    if mean_dist == prev_mse : return  0.01
    elif prev_mse - mean_dist < 0.000001 : return 10
    elif prev_mse - mean_dist < 0.0001 : return 5
    elif prev_mse - mean_dist < 0.001 : return 2
    else : return 1

# %% [markdown]
# ### Initialization

# %%
import numpy as np
from math import sqrt


projection_mat = np.random.uniform(2.0, size=(2, 3))
offset_mat = np.random.uniform(10.0, size=(2, 1))

# %% [markdown]
# ### Processing

# %%
gradient_step = 1
projection_step = (gradient_step, -gradient_step)
offset_step = (gradient_step, -gradient_step)

counter_max = 1000
ratio = 1

mean_dist = get_mean_distance(projection_mat, offset_mat, debug=True)
prev_mse = mean_dist
counter = 0

while gradient_step != 0.0 : # mean_dist > end_threshold :
    
    [[xx, xy, xz], [yx, yy, yz]] = projection_mat
    projection_list = [xx, xy, xz, yx, yy, yz]
    for i in range(6) :
        for step in projection_step :
            projection_list[i] += step
            temp_proj_mat = np.asarray([projection_list[:3], projection_list[3:]])
            dist = get_mean_distance(temp_proj_mat, offset_mat)
            if dist < mean_dist :
                current_best_proj_mat = temp_proj_mat
                mean_dist = dist
            projection_list[i] -= step

    offset_list = list(offset_mat)
    for i in range(2) :
        for step in offset_step :
            offset_list[i] += step
            temp_offset_mat = np.asarray([offset_list[0], offset_list[1]])
            dist = get_mean_distance(projection_mat, temp_offset_mat)
            if dist < mean_dist :
                current_best_proj_mat = None
                current_best_offset_mat = temp_offset_mat
                mean_dist = dist
            offset_list[i] -= step
            
    if current_best_proj_mat is not None :
        projection_mat = current_best_proj_mat
    elif current_best_offset_mat is not None :
        offset_mat = current_best_offset_mat
    else : break
    
    ratio = step_asservissment(mean_dist, prev_mse)
    gradient_step = gradient_step*ratio
    projection_step = (gradient_step, -gradient_step)
    offset_step = (gradient_step, -gradient_step)
    
    print("mean square error :", int(mean_dist), "\n\t\tprogression : ", mean_dist-prev_mse, "\n\t\t\t\tgradient step :", gradient_step)
    prev_mse = mean_dist
# Out:
# mean square error : 6137
# 		progression :  -844.2878409035402
# 				gradient step : 1
# mean square error : 5152
# 		progression :  -984.6452848303061
# 				gradient step : 1
# mean square error : 4345
# 		progression :  -807.4679422488962
# 				gradient step : 1
# mean square error : 3324
# 		progression :  -1020.659295348381
# 				gradient step : 1
# mean square error : 2605
# 		progression :  -718.5585385857262
# 				gradient step : 1
# mean square error : 1581
# 		progression :  -1024.6823189251909
# 				gradient step : 1
# mean square error : 1185
# 		progression :  -395.513043918485
# 				gradient step : 1
# mean square error : 369
# 		progression :  -815.9603559284294
# 				gradient step : 1
# mean square error : 369
# 		progression :  -0.4084603120046495
# 				gradient step : 1
# mean square error : 368
# 		progression :  -0.40514812162660974
# 				gradient step : 1
# mean square error : 368
# 		progression :  -0.4018008286188888
# 				gradient step : 1
# mean square error : 368
# 		progression :  -0.3984172762907292
# 				gradient step : 1
# mean square error : 367
# 		progression :  -0.39499607535645964
# 				gradient step : 1
# mean square error : 367
# 		progression :  -0.3915355713504596
# 				gradient step : 1
# mean square error : 366
# 		progression :  -0.38803382539055065
# 				gradient step : 1
# mean square error : 366
# 		progression :  -0.3844886176703426
# 				gradient step : 1
# mean square error : 366
# 		progression :  -0.3808974828924079
# 				gradient step : 1
# mean square error : 365
# 		progression :  -0.3772577834145636
# 				gradient step : 1
# mean square error : 365
# 		progression :  -0.3735668179838285
# 				gradient step : 1
# mean square error : 365
# 		progression :  -0.3698219515976007
# 				gradient step : 1
# mean square error : 364
# 		progression :  -0.3660207361139669
# 				gradient step : 1
# mean square error : 364
# 		progression :  -0.36216097223245924
# 				gradient step : 1
# mean square error : 363
# 		progression :  -0.3582406427433966
# 				gradient step : 1
# mean square error : 363
# 		progression :  -0.3542576395738024
# 				gradient step : 1
# mean square error : 363
# 		progression :  -0.3502092815712672
# 				gradient step : 1
# mean square error : 362
# 		progression :  -0.34609195270013515
# 				gradient step : 1
# mean square error : 362
# 		progression :  -0.34190202041975226
# 				gradient step : 1
# mean square error : 362
# 		progression :  -0.3376403072117
# 				gradient step : 1
# mean square error : 361
# 		progression :  -0.3333218175340562
# 				gradient step : 1
# mean square error : 361
# 		progression :  -0.3289864250538699
# 				gradient step : 1
# mean square error : 361
# 		progression :  -0.32469703500783
# 				gradient step : 1
# mean square error : 360
# 		progression :  -0.32051680616416434
# 				gradient step : 1
# mean square error : 360
# 		progression :  -0.3164821753820206
# 				gradient step : 1
# mean square error : 360
# 		progression :  -0.3125959196698318
# 				gradient step : 1
# mean square error : 359
# 		progression :  -0.3088392510910012
# 				gradient step : 1
# mean square error : 359
# 		progression :  -0.30518633061751643
# 				gradient step : 1
# mean square error : 359
# 		progression :  -0.30161252223911106
# 				gradient step : 1
# mean square error : 359
# 		progression :  -0.2980971168609585
# 				gradient step : 1
# mean square error : 358
# 		progression :  -0.294623390518268
# 				gradient step : 1
# mean square error : 358
# 		progression :  -0.2911778250661996
# 				gradient step : 1
# mean square error : 358
# 		progression :  -0.2877492510491493
# 				gradient step : 1
# mean square error : 357
# 		progression :  -0.28432812619308834
# 				gradient step : 1
# mean square error : 357
# 		progression :  -0.28090591324826164
# 				gradient step : 1
# mean square error : 357
# 		progression :  -0.27747429507138577
# 				gradient step : 1
# mean square error : 357
# 		progression :  -0.27402339631254335
# 				gradient step : 1
# mean square error : 356
# 		progression :  -0.2705361554014871
# 				gradient step : 1
# mean square error : 356
# 		progression :  -0.26696776015165824
# 				gradient step : 1
# mean square error : 356
# 		progression :  -0.2631725861371592
# 				gradient step : 1
# mean square error : 355
# 		progression :  -0.25887743357128556
# 				gradient step : 1
# mean square error : 355
# 		progression :  -0.2544788402910285
# 				gradient step : 1
# mean square error : 355
# 		progression :  -0.2505964082459968
# 				gradient step : 1
# mean square error : 355
# 		progression :  -0.24701158054972439
# 				gradient step : 1
# mean square error : 354
# 		progression :  -0.24353404057467287
# 				gradient step : 1
# mean square error : 354
# 		progression :  -0.24010338501756223
# 				gradient step : 1
# mean square error : 354
# 		progression :  -0.23669874772235744
# 				gradient step : 1
# mean square error : 354
# 		progression :  -0.23331069762321022
# 				gradient step : 1
# mean square error : 354
# 		progression :  -0.2299336905195446
# 				gradient step : 1
# mean square error : 353
# 		progression :  -0.22656378277707745
# 				gradient step : 1
# mean square error : 353
# 		progression :  -0.22319782048884917
# 				gradient step : 1
# mean square error : 353
# 		progression :  -0.2198330853230459
# 				gradient step : 1
# mean square error : 353
# 		progression :  -0.21646709553328947
# 				gradient step : 1
# mean square error : 352
# 		progression :  -0.21309746915233063
# 				gradient step : 1
# mean square error : 352
# 		progression :  -0.20972182398810446
# 				gradient step : 1
# mean square error : 352
# 		progression :  -0.20633771444022386
# 				gradient step : 1
# mean square error : 352
# 		progression :  -0.2029426106925598
# 				gradient step : 1
# mean square error : 352
# 		progression :  -0.19953377021835195
# 				gradient step : 1
# mean square error : 351
# 		progression :  -0.19491370449179612
# 				gradient step : 1
# mean square error : 351
# 		progression :  -0.19512029427977495
# 				gradient step : 1
# mean square error : 351
# 		progression :  -0.19257805258678218
# 				gradient step : 1
# mean square error : 351
# 		progression :  -0.19389911307297325
# 				gradient step : 1
# mean square error : 351
# 		progression :  -0.1924296503198093
# 				gradient step : 1
# mean square error : 350
# 		progression :  -0.1920195251626069
# 				gradient step : 1
# mean square error : 350
# 		progression :  -0.19225260771401054
# 				gradient step : 1
# mean square error : 350
# 		progression :  -0.19028962585383624
# 				gradient step : 1
# mean square error : 350
# 		progression :  -0.19208294421429173
# 				gradient step : 1
# mean square error : 350
# 		progression :  -0.1899903686183393
# 				gradient step : 1
# mean square error : 350
# 		progression :  -0.19056303139370812
# 				gradient step : 1
# mean square error : 349
# 		progression :  -0.1898600978424838
# 				gradient step : 1
# mean square error : 349
# 		progression :  -0.1889286065336364
# 				gradient step : 1
# mean square error : 349
# 		progression :  -0.18974528538745972
# 				gradient step : 1
# mean square error : 349
# 		progression :  -0.18771030278560374
# 				gradient step : 1
# mean square error : 349
# 		progression :  -0.189251519702907
# 				gradient step : 1
# mean square error : 348
# 		progression :  -0.18762112612239434
# 				gradient step : 1
# mean square error : 348
# 		progression :  -0.18765327660361208
# 				gradient step : 1
# mean square error : 348
# 		progression :  -0.18754143964099512
# 				gradient step : 1
# mean square error : 348
# 		progression :  -0.1860597507240982
# 				gradient step : 1
# mean square error : 348
# 		progression :  -0.18746860141880006
# 				gradient step : 1
# mean square error : 347
# 		progression :  -0.1854759672355044
# 				gradient step : 1
# mean square error : 347
# 		progression :  -0.18638852566903097
# 				gradient step : 1
# mean square error : 347
# 		progression :  -0.18541593555153213
# 				gradient step : 1
# mean square error : 347
# 		progression :  -0.1847790704071599
# 				gradient step : 1
# mean square error : 347
# 		progression :  -0.185358262539296
# 				gradient step : 1
# mean square error : 347
# 		progression :  -0.18339047675624442
# 				gradient step : 1
# mean square error : 346
# 		progression :  -0.18506575521359991
# 				gradient step : 1
# mean square error : 346
# 		progression :  -0.1833429552979169
# 				gradient step : 1
# mean square error : 346
# 		progression :  -0.18341258717714481
# 				gradient step : 1
# mean square error : 346
# 		progression :  -0.18329749144572816
# 				gradient step : 1
# mean square error : 346
# 		progression :  -0.1817334040081846
# 				gradient step : 1
# mean square error : 345
# 		progression :  -0.18325503493542783
# 				gradient step : 1
# mean square error : 345
# 		progression :  -0.18132262304754931
# 				gradient step : 1
# mean square error : 345
# 		progression :  -0.18191896324134404
# 				gradient step : 1
# mean square error : 345
# 		progression :  -0.1812955496836821
# 				gradient step : 1
# mean square error : 345
# 		progression :  -0.18017303029824916
# 				gradient step : 1
# mean square error : 345
# 		progression :  -0.18127540541956932
# 				gradient step : 1
# mean square error : 344
# 		progression :  -0.17936330368922881
# 				gradient step : 1
# mean square error : 344
# 		progression :  -0.18029449079278947
# 				gradient step : 1
# mean square error : 344
# 		progression :  -0.17935793758215368
# 				gradient step : 1
# mean square error : 344
# 		progression :  -0.1784846003681082
# 				gradient step : 1
# mean square error : 344
# 		progression :  -0.17935980692124076
# 				gradient step : 1
# mean square error : 343
# 		progression :  -0.17744003902998884
# 				gradient step : 1
# mean square error : 343
# 		progression :  -0.17857108249756948
# 				gradient step : 1
# mean square error : 343
# 		progression :  -0.17743850898961
# 				gradient step : 1
# mean square error : 343
# 		progression :  -0.17671210484070343
# 				gradient step : 1
# mean square error : 343
# 		progression :  -0.17743355885380652
# 				gradient step : 1
# mean square error : 343
# 		progression :  -0.17540866872502647
# 				gradient step : 1
# mean square error : 342
# 		progression :  -0.17683632634754076
# 				gradient step : 1
# mean square error : 342
# 		progression :  -0.17527868908263144
# 				gradient step : 1
# mean square error : 342
# 		progression :  -0.1750126407094399
# 				gradient step : 1
# mean square error : 342
# 		progression :  -0.17489113715294025
# 				gradient step : 1
# mean square error : 342
# 		progression :  -0.17319902732765513
# 				gradient step : 1
# mean square error : 342
# 		progression :  -0.1733576833312327
# 				gradient step : 1
# mean square error : 341
# 		progression :  -0.1711072493918664
# 				gradient step : 1
# mean square error : 341
# 		progression :  -0.1713892166960136
# 				gradient step : 1
# mean square error : 341
# 		progression :  -0.1709908105031559
# 				gradient step : 1
# mean square error : 341
# 		progression :  -0.16913823093892688
# 				gradient step : 1
# mean square error : 341
# 		progression :  -0.17071216620212226
# 				gradient step : 1
# mean square error : 340
# 		progression :  -0.1690980683433736
# 				gradient step : 1
# mean square error : 340
# 		progression :  -0.16840353853694978
# 				gradient step : 1
# mean square error : 340
# 		progression :  -0.169015428494788
# 				gradient step : 1
# mean square error : 340
# 		progression :  -0.16710472857698733
# 				gradient step : 1
# mean square error : 340
# 		progression :  -0.16790795739768782
# 				gradient step : 1
# mean square error : 340
# 		progression :  -0.16693998405293087
# 				gradient step : 1
# mean square error : 339
# 		progression :  -0.16560607254967863
# 				gradient step : 1
# mean square error : 339
# 		progression :  -0.16671354196421362
# 				gradient step : 1
# mean square error : 339
# 		progression :  -0.16475158766678533
# 				gradient step : 1
# mean square error : 339
# 		progression :  -0.16495185615832497
# 				gradient step : 1
# mean square error : 339
# 		progression :  -0.1644287112536631
# 				gradient step : 1
# mean square error : 339
# 		progression :  -0.16255817375446213
# 				gradient step : 1
# mean square error : 339
# 		progression :  -0.16403182919850678
# 				gradient step : 1
# mean square error : 338
# 		progression :  -0.16199688551154168
# 				gradient step : 1
# mean square error : 338
# 		progression :  -0.16168993144611932
# 				gradient step : 1
# mean square error : 338
# 		progression :  -0.16148317300530834
# 				gradient step : 1
# mean square error : 338
# 		progression :  -0.1593932022198601
# 				gradient step : 1
# mean square error : 338
# 		progression :  -0.16067569987865227
# 				gradient step : 1
# mean square error : 338
# 		progression :  -0.15874969666225525
# 				gradient step : 1
# mean square error : 337
# 		progression :  -0.1580963360820533
# 				gradient step : 1
# mean square error : 337
# 		progression :  -0.15801649391227102
# 				gradient step : 1
# mean square error : 337
# 		progression :  -0.15580633516873377
# 				gradient step : 1
# mean square error : 337
# 		progression :  -0.15687922815573074
# 				gradient step : 1
# mean square error : 337
# 		progression :  -0.1549285488441683
# 				gradient step : 1
# mean square error : 337
# 		progression :  -0.15422325607551102
# 				gradient step : 1
# mean square error : 336
# 		progression :  -0.15396031934989196
# 				gradient step : 1
# mean square error : 336
# 		progression :  -0.15159918546373774
# 				gradient step : 1
# mean square error : 336
# 		progression :  -0.15286735777874583
# 				gradient step : 1
# mean square error : 336
# 		progression :  -0.15048124507688954
# 				gradient step : 1
# mean square error : 336
# 		progression :  -0.15018794519943413
# 				gradient step : 1
# mean square error : 336
# 		progression :  -0.1492796889449437
# 				gradient step : 1
# mean square error : 336
# 		progression :  -0.14752439085407332
# 				gradient step : 1
# mean square error : 335
# 		progression :  -0.14799979532301677
# 				gradient step : 1
# mean square error : 335
# 		progression :  -0.14539789501867517
# 				gradient step : 1
# mean square error : 335
# 		progression :  -0.14613215780980227
# 				gradient step : 1
# mean square error : 335
# 		progression :  -0.14398026287597077
# 				gradient step : 1
# mean square error : 335
# 		progression :  -0.14351514959696487
# 				gradient step : 1
# mean square error : 335
# 		progression :  -0.1424957524978936
# 				gradient step : 1
# mean square error : 335
# 		progression :  -0.1409328679062014
# 				gradient step : 1
# mean square error : 334
# 		progression :  -0.14094899236300762
# 				gradient step : 1
# mean square error : 334
# 		progression :  -0.13838724170375372
# 				gradient step : 1
# mean square error : 334
# 		progression :  -0.1393440266732
# 				gradient step : 1
# mean square error : 334
# 		progression :  -0.1364381371108152
# 				gradient step : 1
# mean square error : 334
# 		progression :  -0.1371254703057616
# 				gradient step : 1
# mean square error : 334
# 		progression :  -0.13472144715814238
# 				gradient step : 1
# mean square error : 334
# 		progression :  -0.13466070162195365
# 				gradient step : 1
# mean square error : 333
# 		progression :  -0.13295589956112508
# 				gradient step : 1
# mean square error : 333
# 		progression :  -0.13223325615240356
# 				gradient step : 1
# mean square error : 333
# 		progression :  -0.13114491834880937
# 				gradient step : 1
# mean square error : 333
# 		progression :  -0.12984105454091832
# 				gradient step : 1
# mean square error : 333
# 		progression :  -0.12929191038699628
# 				gradient step : 1
# mean square error : 333
# 		progression :  -0.1274811191873937
# 				gradient step : 1
# mean square error : 333
# 		progression :  -0.12740023797891808
# 				gradient step : 1
# mean square error : 333
# 		progression :  -0.12514958350641336
# 				gradient step : 1
# mean square error : 332
# 		progression :  -0.12547315234149892
# 				gradient step : 1
# mean square error : 332
# 		progression :  -0.12284179206920953
# 				gradient step : 1
# mean square error : 332
# 		progression :  -0.1235137453589914
# 				gradient step : 1
# mean square error : 332
# 		progression :  -0.12055248268973173
# 				gradient step : 1
# mean square error : 332
# 		progression :  -0.12152496641465405
# 				gradient step : 1
# mean square error : 332
# 		progression :  -0.11827600906514135
# 				gradient step : 1
# mean square error : 332
# 		progression :  -0.1195097275311241
# 				gradient step : 1
# mean square error : 332
# 		progression :  -0.11615834976481665
# 				gradient step : 1
# mean square error : 331
# 		progression :  -0.11731929247912376
# 				gradient step : 1
# mean square error : 331
# 		progression :  -0.11408961264248774
# 				gradient step : 1
# mean square error : 331
# 		progression :  -0.11506116603368355
# 				gradient step : 1
# mean square error : 331
# 		progression :  -0.11200098070543163
# 				gradient step : 1
# mean square error : 331
# 		progression :  -0.11280246268950123
# 				gradient step : 1
# mean square error : 331
# 		progression :  -0.10989454391113895
# 				gradient step : 1
# mean square error : 331
# 		progression :  -0.11054022852277967
# 				gradient step : 1
# mean square error : 331
# 		progression :  -0.10777194396274581
# 				gradient step : 1
# mean square error : 331
# 		progression :  -0.10827260276863626
# 				gradient step : 1
# mean square error : 330
# 		progression :  -0.10563251333718426
# 				gradient step : 1
# mean square error : 330
# 		progression :  -0.10599904578646147
# 				gradient step : 1
# mean square error : 330
# 		progression :  -0.10346085389460313
# 				gradient step : 1
# mean square error : 330
# 		progression :  -0.10371227066866595
# 				gradient step : 1
# mean square error : 330
# 		progression :  -0.10089552926575607
# 				gradient step : 1
# mean square error : 330
# 		progression :  -0.09988883933522175
# 				gradient step : 1
# mean square error : 330
# 		progression :  -0.096969042412411
# 				gradient step : 1
# mean square error : 330
# 		progression :  -0.09689119235400767
# 				gradient step : 1
# mean square error : 330
# 		progression :  -0.0948289261079367
# 				gradient step : 1
# mean square error : 330
# 		progression :  -0.09452602926904774
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.09270443943773898
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.09218393872845354
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.0905829830521725
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.08984117107411294
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.08846650200973727
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.08749369171084709
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.08635565700723191
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.08514021565309804
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.08425012444189406
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.08277977860939245
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.08214898817266203
# 				gradient step : 1
# mean square error : 329
# 		progression :  -0.08041108092749027
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.08005113286674259
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.07803228915088312
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.07795568719114954
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.07564109409713637
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.075862497035871
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.07323501918210695
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.073772531394809
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.07081197837572972
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.07168804984740973
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.06837098618206028
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.06961234877815059
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.06622882455889112
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.06723297643412707
# 				gradient step : 1
# mean square error : 328
# 		progression :  -0.064174919169659
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.06476603341991449
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.06213502236869317
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.06229117438266485
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.06010942153994847
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.05981209102054663
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.05809689563943721
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.05733173954598669
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.05609503995134446
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.054851880907335726
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.05410077250320455
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.05237297458631929
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.052110807078804555
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.0498943368885989
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.050121966957817676
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.04741441852678463
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.0481313203339937
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.044931072989697896
# 				gradient step : 1
# mean square error : 327
# 		progression :  -0.046136194227869964
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.04274462697475201
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.043831271423584894
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.04073402454542929
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.041332574896671304
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.0387141692835371
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.03882031006429543
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.03668369991515874
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.036291387694063815
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.03464191819051621
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.0337428784189342
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.03258888004847904
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.031172254287696433
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.03052532794788476
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.02857755994978106
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.02845246033098192
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.025957408694353035
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.026371625406056864
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.023310770584544116
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.024284063570007675
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.020827559626866332
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.02199983234800129
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.018728934392186147
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.019297126282538102
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.01662583714704624
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.016563609868683216
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.014519533060251888
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.013796122413339162
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.012411436402715026
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.010991121186350483
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.010302515218597819
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.008144532556627837
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.00819273536694709
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.00525083152570005
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.006082866833310163
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.0026002076805866636
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.0036836247130622723
# 				gradient step : 1
# mean square error : 326
# 		progression :  -0.000493730624100408
# 				gradient step : 2
# mean square error : 326
# 		progression :  0.0
# 				gradient step : 0.02
# mean square error : 324
# 		progression :  -2.0426248631408725
# 				gradient step : 0.02
# mean square error : 322
# 		progression :  -1.6006915280085536
# 				gradient step : 0.02
# mean square error : 320
# 		progression :  -1.5947738173223343
# 				gradient step : 0.02
# mean square error : 319
# 		progression :  -1.8901885018523217
# 				gradient step : 0.02
# mean square error : 316
# 		progression :  -2.239184152141661
# 				gradient step : 0.02
# mean square error : 315
# 		progression :  -1.4707066968935578
# 				gradient step : 0.02
# mean square error : 313
# 		progression :  -2.0451743698432665
# 				gradient step : 0.02
# mean square error : 311
# 		progression :  -2.1251869067754683
# 				gradient step : 0.02
# mean square error : 309
# 		progression :  -1.3353944691580182
# 				gradient step : 0.02
# mean square error : 307
# 		progression :  -2.2137704655265793
# 				gradient step : 0.02
# mean square error : 305
# 		progression :  -2.001619621652196
# 				gradient step : 0.02
# mean square error : 304
# 		progression :  -1.1834162639293595
# 				gradient step : 0.02
# mean square error : 302
# 		progression :  -2.4019491452082207
# 				gradient step : 0.02
# mean square error : 300
# 		progression :  -1.8670631435690552
# 				gradient step : 0.02
# mean square error : 298
# 		progression :  -1.173872257795722
# 				gradient step : 0.02
# mean square error : 297
# 		progression :  -1.649614436614911
# 				gradient step : 0.02
# mean square error : 295
# 		progression :  -1.8044093690957652
# 				gradient step : 0.02
# mean square error : 294
# 		progression :  -1.0911055491447428
# 				gradient step : 0.02
# mean square error : 291
# 		progression :  -2.5239121813811494
# 				gradient step : 0.02
# mean square error : 290
# 		progression :  -1.8212610725153695
# 				gradient step : 0.02
# mean square error : 289
# 		progression :  -1.0405158377359953
# 				gradient step : 0.02
# mean square error : 286
# 		progression :  -2.6232308346616264
# 				gradient step : 0.02
# mean square error : 284
# 		progression :  -1.6526032814305154
# 				gradient step : 0.02
# mean square error : 283
# 		progression :  -1.2400776682285368
# 				gradient step : 0.02
# mean square error : 281
# 		progression :  -2.480477295881883
# 				gradient step : 0.02
# mean square error : 279
# 		progression :  -1.465266548570412
# 				gradient step : 0.02
# mean square error : 278
# 		progression :  -1.4633673836735852
# 				gradient step : 0.02
# mean square error : 275
# 		progression :  -2.320348759054241
# 				gradient step : 0.02
# mean square error : 274
# 		progression :  -1.2630188433112721
# 				gradient step : 0.02
# mean square error : 272
# 		progression :  -1.7083380925963638
# 				gradient step : 0.02
# mean square error : 270
# 		progression :  -2.1400363015626453
# 				gradient step : 0.02
# mean square error : 269
# 		progression :  -1.1383132679846426
# 				gradient step : 0.02
# mean square error : 267
# 		progression :  -1.7847839221498702
# 				gradient step : 0.02
# mean square error : 265
# 		progression :  -1.8014429598711672
# 				gradient step : 0.02
# mean square error : 264
# 		progression :  -1.1645819040171546
# 				gradient step : 0.02
# mean square error : 263
# 		progression :  -1.772189288129141
# 				gradient step : 0.02
# mean square error : 260
# 		progression :  -2.1261086922265804
# 				gradient step : 0.02
# mean square error : 259
# 		progression :  -0.9367056617842877
# 				gradient step : 0.02
# mean square error : 257
# 		progression :  -2.057635457776712
# 				gradient step : 0.02
# mean square error : 256
# 		progression :  -1.910545204872733
# 				gradient step : 0.02
# mean square error : 254
# 		progression :  -1.0612138102901838
# 				gradient step : 0.02
# mean square error : 253
# 		progression :  -1.801206883815297
# 				gradient step : 0.02
# mean square error : 251
# 		progression :  -1.7627657816253475
# 				gradient step : 0.02
# mean square error : 250
# 		progression :  -0.8312398120771718
# 				gradient step : 0.02
# mean square error : 248
# 		progression :  -2.1109122416127093
# 				gradient step : 0.02
# mean square error : 246
# 		progression :  -1.9034936495589534
# 				gradient step : 0.02
# mean square error : 245
# 		progression :  -0.7676930171156755
# 				gradient step : 0.02
# mean square error : 243
# 		progression :  -2.0911251006039606
# 				gradient step : 0.02
# mean square error : 241
# 		progression :  -1.7434756262888982
# 				gradient step : 0.02
# mean square error : 241
# 		progression :  -0.7249084115327378
# 				gradient step : 0.02
# mean square error : 238
# 		progression :  -2.246115323248347
# 				gradient step : 0.02
# mean square error : 237
# 		progression :  -1.840856205420181
# 				gradient step : 0.02
# mean square error : 236
# 		progression :  -0.6892034209692781
# 				gradient step : 0.02
# mean square error : 234
# 		progression :  -2.1626971653833493
# 				gradient step : 0.02
# mean square error : 232
# 		progression :  -1.717540426273274
# 				gradient step : 0.02
# mean square error : 231
# 		progression :  -0.5839863595551833
# 				gradient step : 0.02
# mean square error : 229
# 		progression :  -2.418327991150676
# 				gradient step : 0.02
# mean square error : 227
# 		progression :  -1.7611167786056683
# 				gradient step : 0.02
# mean square error : 227
# 		progression :  -0.5869564466685233
# 				gradient step : 0.02
# mean square error : 224
# 		progression :  -2.2653521908079597
# 				gradient step : 0.02
# mean square error : 223
# 		progression :  -1.6637648317811227
# 				gradient step : 0.02
# mean square error : 222
# 		progression :  -0.42488162962504816
# 				gradient step : 0.02
# mean square error : 220
# 		progression :  -2.6287432174844696
# 				gradient step : 0.02
# mean square error : 218
# 		progression :  -1.6446519495761436
# 				gradient step : 0.02
# mean square error : 218
# 		progression :  -0.4795212261192603
# 				gradient step : 0.02
# mean square error : 215
# 		progression :  -2.3862000074510377
# 				gradient step : 0.02
# mean square error : 214
# 		progression :  -1.593980091524628
# 				gradient step : 0.02
# mean square error : 213
# 		progression :  -0.3091667721167539
# 				gradient step : 0.02
# mean square error : 211
# 		progression :  -2.6350767910569743
# 				gradient step : 0.02
# mean square error : 210
# 		progression :  -1.0682127667222971
# 				gradient step : 0.02
# mean square error : 209
# 		progression :  -0.857045979605175
# 				gradient step : 0.02
# mean square error : 206
# 		progression :  -2.386690356757299
# 				gradient step : 0.02
# mean square error : 206
# 		progression :  -0.7161883919505669
# 				gradient step : 0.02
# mean square error : 204
# 		progression :  -1.2426506551055354
# 				gradient step : 0.02
# mean square error : 202
# 		progression :  -1.943680494595469
# 				gradient step : 0.02
# mean square error : 202
# 		progression :  -0.31169998338521054
# 				gradient step : 0.02
# mean square error : 199
# 		progression :  -2.9888099069250984
# 				gradient step : 0.02
# mean square error : 198
# 		progression :  -1.5419215344203394
# 				gradient step : 0.02
# mean square error : 197
# 		progression :  -0.7392766592418241
# 				gradient step : 0.02
# mean square error : 194
# 		progression :  -2.6861504342912212
# 				gradient step : 0.02
# mean square error : 193
# 		progression :  -1.1100859406652148
# 				gradient step : 0.02
# mean square error : 192
# 		progression :  -1.246124527289254
# 				gradient step : 0.02
# mean square error : 190
# 		progression :  -2.323965688181687
# 				gradient step : 0.02
# mean square error : 189
# 		progression :  -0.6082019900208309
# 				gradient step : 0.02
# mean square error : 187
# 		progression :  -1.8420124397237316
# 				gradient step : 0.02
# mean square error : 185
# 		progression :  -1.8957168724643054
# 				gradient step : 0.02
# mean square error : 185
# 		progression :  -0.2651417505428526
# 				gradient step : 0.02
# mean square error : 183
# 		progression :  -2.3246459463613007
# 				gradient step : 0.02
# mean square error : 181
# 		progression :  -1.7827798831648067
# 				gradient step : 0.02
# mean square error : 181
# 		progression :  -0.25497139888832976
# 				gradient step : 0.02
# mean square error : 178
# 		progression :  -2.2699591899471443
# 				gradient step : 0.02
# mean square error : 177
# 		progression :  -1.642762392310317
# 				gradient step : 0.02
# mean square error : 177
# 		progression :  -0.046017679014624946
# 				gradient step : 0.02
# mean square error : 174
# 		progression :  -2.536255227976312
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -1.6833491940471674
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017979144213313702
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017934142345552573
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017889054945499083
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001784388524242786
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001779863691922401
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017753314114372643
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017707921452085884
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001766246398574367
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017616947238821012
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017571377129570465
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001752576002530759
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017480102627871474
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017434412010857159
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017388695550550892
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017342960889834558
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017297215883331774
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017251468578649565
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001720572713651336
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017159999771081402
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017114294737723412
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017068620226154962
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0017022984341110714
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016977395039816656
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016931860073441385
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016886386944747755
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016840982873418398
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016795654723580355
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016750409001531352
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016705251807138666
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001666018880939646
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001661522522397263
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016570365785355534
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016525614777549436
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001648097595705167
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016436452638401988
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.00163920476066437
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016347763194630716
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016303601256879574
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016259563190317294
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016215649978903457
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001617186215099764
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016128199866898285
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016084662897242197
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0016041250660805417
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015997962263440968
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015954796490973422
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015911751862915935
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015868826637586153
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015826018851043955
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015783326331586522
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001574074672049619
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001569827750387276
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015655916016612537
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001561365948873572
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015571505028333377
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015529449673010731
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015487490384771263
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015445624064795993
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015403847591812792
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015383487064752899
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015382522697677814
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015368040484418088
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015361222836247634
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015352581961565193
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015339946012886685
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001533711248725922
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015318690321635131
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001532163299941658
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015297453971641062
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015306144375415442
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015276235222358991
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015290647456822626
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015255065174812898
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015275110297920946
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015239586434745434
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001525388946674866
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015224099475972253
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001523268368060826
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001520860505223709
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015211491408990696
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001519310390051487
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001519031113929259
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015177596740727495
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015169141423427845
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015162084268069975
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001514798082098423
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015146567184842752
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015126827913434227
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015131046181693364
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015105681298734908
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015115521936195364
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015084539597864932
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015099995150364975
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015064626486775978
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015083241443392126
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015049105374487226
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015062096735505293
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015033581555314868
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015040955054530514
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015018055733264646
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015019815033952
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0015002528617742428
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014998675300716968
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014987000942880968
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014977534453350927
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014971473478908592
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014956391068494668
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014955947015948823
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001493524368186172
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014940422391021002
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014914090792217394
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.00149249004815033
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014892930849157437
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014909382212238143
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014873996045139393
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014891634759806038
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001485846758811249
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014870476276485078
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014842942477457655
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014849309134774558
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014827421716745448
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014828131668309652
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001481190638969565
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014806942113523291
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014796397676946071
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014785738622151712
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014780896848662906
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001476451919018018
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014765405285857014
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014743281701043998
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014749924503689726
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001472202385144783
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014734456154883446
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014700743160176444
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014719002061553965
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014683260267247533
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014699740893888702
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014667768170113504
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001467847889927043
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014652289657135498
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001465719249409858
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014636826838625439
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014635878726210194
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001462138206875352
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001461453427282322
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014605958023423682
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001459315542490458
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014590557710789653
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014571737975472843
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014575184583236478
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.00145502771226802
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014559842584560556
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014528767350441285
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014544536271330344
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014507858205945467
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014528614986204502
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014492450229681708
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001450717688101122
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014477075351351232
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014485688480192493
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001446173913052462
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014464142325891771
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.001444644821191332
# 				gradient step : 0.02
# mean square error : 172
# 		progression :  -0.0014442529433438267
# 				gradient step : 0.02
# ...
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0015942081511894912
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0015957246922653212
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.001562010705697503
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.001554980613235557
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0015298480601586562
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0015147692132870816
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0014977453029274557
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0014750267539938022
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.001465712746266945
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0014356997973550278
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0014337504437520465
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0013967444792513106
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0014018507899606902
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0013622177468306518
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.001365906965830277
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.001330216477001045
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0013277721276097054
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0012982252248008308
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.001289909033758363
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0012662082423986476
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0012522946174584604
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0012341200393422014
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.001214905167827851
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0012019031388632584
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.001177713260133828
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0011694856053878766
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0011406835439515817
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0011367786070763941
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0011037668057838346
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0011036745642911683
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0010668915794838085
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0010700470767375236
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.001029952542069168
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.0010357549713120306
# 				gradient step : 0.048566722305643274
# mean square error : 79
# 		progression :  -0.000993017498430504
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.001955632506621896
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.0018858484509252094
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.0018006965698305066
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.0017362614883893457
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.00163499974594572
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.0015840972458818214
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.0014557943257500483
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.0014380245386007573
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.0012839664163095676
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.001287679113147533
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.0011565475093817668
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.001102611832124012
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.0010377973160018428
# 				gradient step : 0.09713344461128655
# mean square error : 79
# 		progression :  -0.0009190967941634653
# 				gradient step : 0.1942668892225731
# mean square error : 79
# 		progression :  -0.0017159129385504457
# 				gradient step : 0.1942668892225731
# mean square error : 79
# 		progression :  -0.0013270062471946176
# 				gradient step : 0.1942668892225731
# mean square error : 79
# 		progression :  -0.0013143042705507924
# 				gradient step : 0.1942668892225731
# mean square error : 79
# 		progression :  -0.0007946892402657113
# 				gradient step : 0.3885337784451462
# mean square error : 79
# 		progression :  -0.00075324290000367
# 				gradient step : 0.7770675568902924
# mean square error : 79
# 		progression :  0.0
# 				gradient step : 0.007770675568902924
# mean square error : 79
# 		progression :  -3.485262783442522e-05
# 				gradient step : 0.03885337784451462
# mean square error : 79
# 		progression :  -0.00016210727595478147
# 				gradient step : 0.07770675568902924
# mean square error : 79
# 		progression :  -0.0002633475499749238
# 				gradient step : 0.15541351137805848
# mean square error : 79
# 		progression :  -0.000282225314734319
# 				gradient step : 0.31082702275611696
# mean square error : 79
# 		progression :  0.0
# 				gradient step : 0.0031082702275611698
# mean square error : 79
# 		progression :  -0.11921725895579982
# 				gradient step : 0.0031082702275611698
# mean square error : 79
# 		progression :  -0.07753988146458823
# 				gradient step : 0.0031082702275611698
# mean square error : 79
# 		progression :  -0.02298375585083079
# 				gradient step : 0.0031082702275611698
# mean square error : 79
# 		progression :  -0.0001793903631437388
# 				gradient step : 0.0062165404551223396
# mean square error : 79
# 		progression :  -0.00035836588909887723
# 				gradient step : 0.012433080910244679
# mean square error : 79
# 		progression :  -0.0007150715512409533
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0014234951852074573
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0014146179834284567
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0014057249023267104
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0013968160913861993
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0013878917369396504
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.001378952057280003
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0013699972923859605
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0013610276976123714
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0013520435345384385
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0013430450622138324
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0013340325270121411
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0013250061570744265
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0013159661515089738
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0013069126728311176
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0012978458407246762
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.001288765725306007
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.001279672340842808
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0012705656415192834
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0012614455185513407
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.001252311795951755
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0012431642304164825
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0012340025098893648
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.001224826256191136
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0012156350229872714
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0012064283031776313
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0011972055287827743
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0011879660774098966
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.001178709277468215
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0011694344131711887
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0011601407334893565
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0011508274560441123
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.001141493778860081
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0011321388846710079
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0011227619517200083
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0011133621621439715
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0011039387084110786
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0010944908053716063
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0010850176958712154
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0010755186604853861
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0010659930255343397
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0010564401706290028
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0010468595357622235
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0010372506293379047
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.001027613031482133
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0010179464033370778
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0010082504886668175
# 				gradient step : 0.024866161820489358
# mean square error : 79
# 		progression :  -0.0009985251191722
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0019677560134709893
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0019285008949907478
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0018890134717395313
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0018492998709689346
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0018093689351275088
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0017692319121778155
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.001728902052519743
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0016883941428034177
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0016477240041155028
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0016069079981946288
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0015659625628359208
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0015249038084022004
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0014837471884163733
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.001442507250587255
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0014011974669898564
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0013598301325430384
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0013184163192505594
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0013066325573731774
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0012848703342740464
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0012661858132076986
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0012514001958408016
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.001225822859822756
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.001218010740842601
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0011855142017793696
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.001184710486882068
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.001145233256650613
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0011515115383105012
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.001110321382483903
# 				gradient step : 0.049732323640978716
# mean square error : 79
# 		progression :  -0.0011130647331611954
# 				gradient step : 0.049732323640978716
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-149-3adce5466461> in <module>
#      29             offset_list[i] += step
#      30             temp_offset_mat = np.asarray([offset_list[0], offset_list[1]])
# ---> 31             dist = get_mean_distance(projection_mat, temp_offset_mat)
#      32             if dist < mean_dist :
#      33                 current_best_proj_mat = None
#
# <ipython-input-147-73f330d821b2> in get_mean_distance(projection_mat, offset_mat, debug)
#       6             if x_truth == 0 and y_truth == 0 : continue # bad acquisition; so we skip these numbers
#       7             x_projection, y_projection = np.add(projection_mat.dot(articulation_3d), offset_mat)
# ----> 8             dist = sqrt((x_truth-x_projection)**2 + (y_truth-y_projection)**2)
#       9             total_dist.append(dist)
#      10     mean_dist = sum(total_dist) / len(total_dist)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Verification

# %%
print(projection_mat)
print()
print(offset_mat)
# Out:
# [[ 0.05241897 -0.13417533 -0.00497104]
#  [-0.00236236  0.00797051 -0.25118345]]
#
# [[1031.45356893]
#  [ 855.62283821]]

# %%
from statistics import stdev

dist_list = []
for frame_3d, frame_2d in zip(coords_3d_frames, coords_2d_frames) :
    for articulation_3d, articulation_2d in zip(frame_3d, frame_2d) :
        x_truth, y_truth = articulation_2d
        if x_truth == 0 and y_truth == 0 :
            continue # bad acquisition; so we skip these numbers
        x_projection, y_projection = np.add(projection_mat.dot(articulation_3d), offset_mat)
        print('projection\t: ', np.round(x_projection, 2), np.round(y_projection, 2))
        print('truth\t\t: ', x_truth, y_truth)
        dist_list.append(sqrt((x_truth-x_projection)**2 + (y_truth-y_projection)**2))
        print()
# Out:
# projection	:  [902.51] [490.37]
# truth		:  [895.262] [483.256]
#
# projection	:  [959.41] [482.4]
# truth		:  [960.043] [480.277]
#
# projection	:  [905.12] [575.02]
# truth		:  [898.239] [556.855]
#
# projection	:  [967.07] [566.15]
# truth		:  [971.82] [577.444]
#
# projection	:  [922.92] [588.99]
# truth		:  [886.436] [597.962]
#
# projection	:  [935.22] [592.39]
# truth		:  [907.006] [603.953]
#
# projection	:  [902.21] [489.71]
# truth		:  [895.271] [483.254]
#
# projection	:  [959.95] [481.97]
# truth		:  [960.065] [480.303]
#
# projection	:  [901.51] [573.44]
# truth		:  [898.181] [556.802]
#
# projection	:  [972.07] [564.55]
# truth		:  [971.819] [580.311]
#
# projection	:  [913.64] [587.03]
# truth		:  [883.597] [586.231]
#
# projection	:  [943.35] [591.35]
# truth		:  [907.056] [603.919]
#
# projection	:  [902.15] [488.85]
# truth		:  [895.264] [483.287]
#
# projection	:  [960.54] [482.]
# truth		:  [960.034] [480.29]
#
# projection	:  [895.33] [569.89]
# truth		:  [892.314] [559.772]
#
# projection	:  [979.37] [560.21]
# truth		:  [974.776] [577.501]
#
# projection	:  [895.24] [589.64]
# truth		:  [877.613] [594.97]
#
# projection	:  [959.04] [593.35]
# truth		:  [907.042] [609.808]
#
# projection	:  [902.26] [487.31]
# truth		:  [895.233] [483.284]
#
# projection	:  [961.15] [481.02]
# truth		:  [960.038] [480.283]
#
# projection	:  [891.13] [564.78]
# truth		:  [889.389] [559.731]
#
# projection	:  [985.12] [554.45]
# truth		:  [977.62] [577.439]
#
# projection	:  [879.99] [587.]
# truth		:  [874.619] [595.002]
#
# projection	:  [973.45] [591.17]
# truth		:  [918.798] [612.742]
#
# projection	:  [902.92] [486.16]
# truth		:  [892.369] [483.316]
#
# projection	:  [961.25] [480.34]
# truth		:  [960.042] [480.274]
#
# projection	:  [890.16] [560.39]
# truth		:  [883.613] [571.365]
#
# projection	:  [987.92] [550.35]
# truth		:  [980.651] [577.335]
#
# projection	:  [872.44] [582.68]
# truth		:  [859.852] [600.82]
#
# projection	:  [981.37] [588.57]
# truth		:  [930.566] [621.466]
#
# projection	:  [904.2] [485.56]
# truth		:  [895.207] [483.319]
#
# projection	:  [961.07] [480.55]
# truth		:  [962.929] [480.247]
#
# projection	:  [892.19] [558.71]
# truth		:  [883.41] [571.488]
#
# projection	:  [988.38] [549.62]
# truth		:  [986.5] [574.541]
#
# projection	:  [871.53] [582.59]
# truth		:  [853.989] [600.962]
#
# projection	:  [982.27] [590.03]
# truth		:  [948.188] [618.511]
#
# projection	:  [906.01] [485.2]
# truth		:  [895.238] [483.308]
#
# projection	:  [960.72] [480.83]
# truth		:  [962.959] [480.223]
#
# projection	:  [896.53] [559.51]
# truth		:  [880.517] [574.271]
#
# projection	:  [987.11] [551.38]
# truth		:  [995.275] [574.371]
#
# projection	:  [875.9] [586.92]
# truth		:  [836.384] [601.02]
#
# projection	:  [976.4] [595.62]
# truth		:  [954.019] [618.587]
#
# projection	:  [908.78] [484.83]
# truth		:  [895.259] [483.276]
#
# projection	:  [959.86] [481.2]
# truth		:  [960.079] [480.234]
#
# projection	:  [902.62] [561.07]
# truth		:  [880.381] [571.393]
#
# projection	:  [983.93] [554.82]
# truth		:  [998.27] [571.384]
#
# projection	:  [884.52] [593.74]
# truth		:  [833.298] [600.842]
#
# projection	:  [964.94] [602.75]
# truth		:  [962.931] [615.634]
#
# projection	:  [912.76] [484.55]
# truth		:  [895.257] [483.288]
#
# projection	:  [958.16] [481.97]
# truth		:  [960.005] [480.232]
#
# projection	:  [910.03] [562.43]
# truth		:  [880.363] [568.51]
#
# projection	:  [977.93] [559.97]
# truth		:  [998.304] [565.604]
#
# projection	:  [895.5] [599.9]
# truth		:  [833.357] [597.994]
#
# projection	:  [950.43] [608.1]
# truth		:  [974.566] [621.363]
#
# projection	:  [917.97] [484.21]
# truth		:  [898.126] [483.262]
#
# projection	:  [954.75] [482.67]
# truth		:  [957.127] [480.278]
#
# projection	:  [918.09] [563.13]
# truth		:  [880.458] [565.634]
#
# projection	:  [969.19] [564.34]
# truth		:  [998.397] [565.544]
#
# projection	:  [906.36] [603.51]
# truth		:  [833.392] [597.835]
#
# projection	:  [936.63] [609.61]
# truth		:  [974.779] [621.369]
#
# projection	:  [924.04] [483.89]
# truth		:  [895.295] [483.264]
#
# projection	:  [949.95] [483.99]
# truth		:  [957.065] [480.235]
#
# projection	:  [926.98] [562.91]
# truth		:  [880.537] [565.591]
#
# projection	:  [959.21] [567.52]
# truth		:  [998.383] [562.634]
#
# projection	:  [914.27] [604.31]
# truth		:  [833.477] [597.833]
#
# projection	:  [926.27] [606.42]
# truth		:  [974.796] [621.419]
#
# projection	:  [929.8] [482.63]
# truth		:  [898.121] [483.255]
#
# projection	:  [944.56] [484.85]
# truth		:  [957.063] [480.219]
#
# projection	:  [935.81] [560.99]
# truth		:  [880.566] [562.71]
#
# projection	:  [949.72] [568.83]
# truth		:  [998.364] [562.698]
#
# projection	:  [918.54] [603.67]
# truth		:  [833.462] [595.093]
#
# projection	:  [919.33] [603.49]
# truth		:  [974.792] [621.551]
#
# projection	:  [933.86] [480.45]
# truth		:  [901.041] [483.21]
#
# projection	:  [939.67] [483.46]
# truth		:  [957.104] [480.186]
#
# projection	:  [943.33] [557.78]
# truth		:  [883.453] [559.742]
#
# projection	:  [941.99] [566.79]
# truth		:  [998.3] [565.563]
#
# projection	:  [920.51] [601.5]
# truth		:  [833.526] [597.93]
#
# projection	:  [914.64] [602.41]
# truth		:  [974.586] [624.433]
#
# projection	:  [937.36] [480.32]
# truth		:  [901.123] [483.235]
#
# projection	:  [934.91] [482.98]
# truth		:  [957.048] [480.096]
#
# projection	:  [949.26] [556.27]
# truth		:  [883.625] [559.765]
#
# projection	:  [935.19] [565.9]
# truth		:  [998.211] [568.482]
#
# projection	:  [921.03] [599.07]
# truth		:  [836.286] [598.065]
#
# projection	:  [910.93] [600.91]
# truth		:  [968.77] [630.431]
#
# projection	:  [940.54] [481.19]
# truth		:  [901.169] [483.175]
#
# projection	:  [929.59] [483.44]
# truth		:  [957.001] [480.106]
#
# projection	:  [954.18] [556.82]
# truth		:  [892.283] [565.654]
#
# projection	:  [928.33] [566.42]
# truth		:  [995.36] [568.575]
#
# projection	:  [920.87] [596.61]
# truth		:  [839.331] [601.093]
#
# projection	:  [907.42] [600.53]
# truth		:  [957.025] [633.32]
#
# projection	:  [943.02] [482.4]
# truth		:  [903.969] [483.093]
#
# projection	:  [923.68] [482.84]
# truth		:  [954.255] [480.14]
#
# projection	:  [957.92] [558.49]
# truth		:  [901.045] [565.591]
#
# projection	:  [920.88] [566.01]
# truth		:  [995.261] [574.3]
#
# projection	:  [920.93] [594.13]
# truth		:  [845.263] [603.919]
#
# projection	:  [903.8] [599.15]
# truth		:  [951.153] [639.13]
#
# projection	:  [945.03] [484.3]
# truth		:  [904.048] [483.125]
#
# projection	:  [917.19] [481.05]
# truth		:  [954.196] [480.129]
#
# projection	:  [960.44] [560.95]
# truth		:  [903.957] [565.594]
#
# projection	:  [912.81] [564.25]
# truth		:  [989.378] [577.279]
#
# projection	:  [921.21] [592.25]
# truth		:  [853.984] [603.984]
#
# projection	:  [900.49] [596.47]
# truth		:  [936.472] [642.07]
#
# projection	:  [946.11] [485.96]
# truth		:  [906.921] [483.145]
#
# projection	:  [910.72] [480.33]
# truth		:  [954.067] [480.104]
#
# projection	:  [962.08] [563.11]
# truth		:  [904.051] [571.469]
#
# projection	:  [904.58] [563.19]
# truth		:  [977.789] [577.394]
#
# projection	:  [921.82] [590.7]
# truth		:  [859.828] [615.645]
#
# projection	:  [897.35] [593.63]
# truth		:  [927.703] [642.157]
#
# projection	:  [946.8] [485.79]
# truth		:  [907.049] [483.086]
#
# projection	:  [904.57] [480.37]
# truth		:  [954.044] [477.324]
#
# projection	:  [962.64] [563.92]
# truth		:  [906.966] [571.536]
#
# projection	:  [897.29] [563.03]
# truth		:  [974.805] [577.516]
#
# projection	:  [922.65] [589.7]
# truth		:  [862.942] [618.607]
#
# projection	:  [895.18] [591.4]
# truth		:  [921.701] [645.056]
#
# projection	:  [947.85] [484.92]
# truth		:  [915.818] [480.346]
#
# projection	:  [898.42] [480.46]
# truth		:  [951.239] [480.126]
#
# projection	:  [962.94] [564.25]
# truth		:  [915.899] [568.514]
#
# projection	:  [890.81] [562.88]
# truth		:  [971.648] [583.336]
#
# projection	:  [923.55] [588.]
# truth		:  [877.632] [618.605]
#
# projection	:  [895.45] [589.35]
# truth		:  [907.023] [645.072]
#
# projection	:  [947.76] [484.93]
# truth		:  [918.764] [480.274]
#
# projection	:  [892.44] [481.88]
# truth		:  [951.122] [477.281]
#
# projection	:  [962.63] [564.9]
# truth		:  [918.829] [571.475]
#
# projection	:  [884.89] [564.35]
# truth		:  [959.957] [580.428]
#
# projection	:  [924.88] [586.98]
# truth		:  [880.51] [621.426]
#
# projection	:  [897.18] [588.81]
# truth		:  [903.973] [642.07]
#
# projection	:  [946.42] [484.73]
# truth		:  [924.74] [480.214]
#
# projection	:  [886.87] [483.15]
# truth		:  [951.087] [477.258]
#
# projection	:  [960.98] [565.08]
# truth		:  [921.753] [574.482]
#
# projection	:  [879.67] [566.02]
# truth		:  [951.295] [586.251]
#
# projection	:  [926.5] [586.57]
# truth		:  [883.573] [621.607]
#
# projection	:  [898.35] [590.03]
# truth		:  [898.143] [639.188]
#
# projection	:  [943.31] [485.23]
# truth		:  [933.489] [474.401]
#
# projection	:  [881.48] [484.68]
# truth		:  [948.151] [477.305]
#
# projection	:  [957.69] [565.85]
# truth		:  [930.704] [580.355]
#
# projection	:  [874.28] [567.43]
# truth		:  [948.191] [592.08]
#
# projection	:  [898.4] [590.52]
# truth		:  [889.35] [633.247]
#
# projection	:  [938.2] [486.31]
# truth		:  [945.28] [468.48]
#
# projection	:  [875.56] [485.91]
# truth		:  [945.21] [477.281]
#
# projection	:  [952.67] [566.59]
# truth		:  [936.548] [577.395]
#
# projection	:  [868.27] [568.51]
# truth		:  [939.348] [589.145]
#
# projection	:  [896.63] [590.26]
# truth		:  [883.601] [633.26]
#
# projection	:  [931.17] [488.35]
# truth		:  [951.201] [465.546]
#
# projection	:  [868.9] [486.95]
# truth		:  [939.397] [477.23]
#
# projection	:  [945.96] [567.9]
# truth		:  [948.189] [577.332]
#
# projection	:  [861.69] [569.24]
# truth		:  [927.709] [589.105]
#
# projection	:  [924.57] [583.78]
# truth		:  [904.114] [639.068]
#
# projection	:  [893.46] [589.21]
# truth		:  [883.494] [630.396]
#
# projection	:  [923.85] [487.81]
# truth		:  [951.117] [465.504]
#
# projection	:  [861.98] [485.56]
# truth		:  [933.602] [474.382]
#
# projection	:  [938.41] [567.27]
# truth		:  [951.026] [586.165]
#
# projection	:  [855.01] [567.27]
# truth		:  [927.495] [580.406]
#
# projection	:  [889.03] [586.16]
# truth		:  [883.483] [630.343]
#
# projection	:  [916.36] [486.82]
# truth		:  [951.179] [459.803]
#
# projection	:  [855.39] [483.94]
# truth		:  [930.721] [471.378]
#
# projection	:  [931.95] [564.53]
# truth		:  [948.238] [574.489]
#
# projection	:  [848.48] [565.07]
# truth		:  [924.559] [577.491]
#
# projection	:  [884.25] [583.05]
# truth		:  [883.412] [624.525]
#
# projection	:  [910.01] [484.98]
# truth		:  [954.05] [462.647]
#
# projection	:  [849.38] [483.31]
# truth		:  [930.504] [468.455]
#
# projection	:  [925.32] [563.18]
# truth		:  [945.246] [568.498]
#
# projection	:  [839.18] [563.1]
# truth		:  [912.997] [574.408]
#
# projection	:  [873.14] [591.33]
# truth		:  [883.609] [621.542]
#
# projection	:  [904.31] [482.79]
# truth		:  [954.063] [462.623]
#
# projection	:  [844.33] [482.22]
# truth		:  [927.697] [465.511]
#
# projection	:  [923.06] [558.01]
# truth		:  [951.117] [550.898]
#
# projection	:  [831.92] [560.99]
# truth		:  [921.752] [547.955]
#
# projection	:  [864.08] [595.94]
# truth		:  [886.452] [618.493]
#
# projection	:  [900.51] [481.15]
# truth		:  [954.137] [462.658]
#
# projection	:  [840.81] [482.35]
# truth		:  [924.644] [462.7]
#
# projection	:  [922.3] [553.44]
# truth		:  [951.109] [550.832]
#
# projection	:  [829.04] [561.85]
# truth		:  [910.064] [544.968]
#
# projection	:  [923.77] [526.7]
# truth		:  [904.103] [601.033]
#
# projection	:  [860.81] [597.67]
# truth		:  [889.338] [606.796]
#
# projection	:  [898.16] [480.95]
# truth		:  [954.192] [465.546]
#
# projection	:  [839.22] [483.28]
# truth		:  [921.67] [468.439]
#
# projection	:  [922.05] [551.3]
# truth		:  [954.168] [556.763]
#
# projection	:  [827.96] [563.55]
# truth		:  [906.899] [553.817]
#
# projection	:  [923.48] [515.02]
# truth		:  [921.614] [603.842]
#
# projection	:  [860.28] [600.12]
# truth		:  [883.57] [609.766]
#
# projection	:  [897.8] [481.14]
# truth		:  [957.071] [471.373]
#
# projection	:  [838.97] [484.08]
# truth		:  [915.814] [465.604]
#
# projection	:  [922.52] [550.43]
# truth		:  [968.842] [568.544]
#
# projection	:  [828.04] [564.73]
# truth		:  [904.093] [553.913]
#
# projection	:  [924.02] [506.53]
# truth		:  [915.872] [603.961]
#
# projection	:  [860.73] [601.94]
# truth		:  [880.646] [609.795]
#
# projection	:  [899.22] [480.42]
# truth		:  [957.141] [474.3]
#
# projection	:  [839.35] [484.22]
# truth		:  [910.049] [468.518]
#
# projection	:  [924.79] [546.71]
# truth		:  [974.664] [574.299]
#
# projection	:  [828.64] [565.03]
# truth		:  [901.117] [550.887]
#
# projection	:  [926.03] [497.84]
# truth		:  [927.637] [606.755]
#
# projection	:  [861.07] [602.71]
# truth		:  [880.507] [603.943]
#
# projection	:  [900.57] [480.48]
# truth		:  [957.086] [477.233]
#
# projection	:  [840.24] [484.1]
# truth		:  [907.135] [471.428]
#
# projection	:  [925.75] [545.51]
# truth		:  [974.667] [577.25]
#
# projection	:  [829.41] [565.11]
# truth		:  [886.455] [562.671]
#
# projection	:  [927.37] [494.71]
# truth		:  [930.583] [606.817]
#
# projection	:  [861.22] [603.49]
# truth		:  [871.745] [621.569]
#
# projection	:  [901.64] [481.78]
# truth		:  [959.954] [480.109]
#
# projection	:  [841.36] [484.07]
# truth		:  [906.951] [468.53]
#
# projection	:  [926.65] [544.93]
# truth		:  [974.681] [577.427]
#
# projection	:  [830.31] [565.16]
# truth		:  [883.599] [550.928]
#
# projection	:  [926.99] [493.91]
# truth		:  [933.514] [606.797]
#
# projection	:  [861.25] [604.25]
# truth		:  [877.552] [609.808]
#
# projection	:  [902.93] [482.32]
# truth		:  [960.002] [480.198]
#
# projection	:  [842.42] [483.78]
# truth		:  [904.001] [471.433]
#
# projection	:  [926.82] [546.48]
# truth		:  [974.651] [580.263]
#
# projection	:  [831.08] [564.77]
# truth		:  [880.536] [562.692]
#
# projection	:  [927.15] [494.68]
# truth		:  [927.659] [609.79]
#
# projection	:  [861.58] [604.97]
# truth		:  [877.592] [609.738]
#
# projection	:  [904.24] [482.44]
# truth		:  [957.149] [480.237]
#
# projection	:  [842.99] [483.33]
# truth		:  [898.236] [474.333]
#
# projection	:  [927.23] [547.29]
# truth		:  [974.703] [577.523]
#
# projection	:  [831.59] [564.32]
# truth		:  [877.56] [568.535]
#
# projection	:  [927.67] [496.11]
# truth		:  [930.537] [609.753]
#
# projection	:  [861.97] [604.5]
# truth		:  [877.564] [612.729]
#
# projection	:  [904.26] [483.29]
# truth		:  [957.134] [480.328]
#
# projection	:  [843.52] [483.29]
# truth		:  [889.42] [474.344]
#
# projection	:  [927.35] [548.24]
# truth		:  [974.778] [577.447]
#
# projection	:  [831.85] [564.11]
# truth		:  [862.886] [574.454]
#
# projection	:  [927.57] [496.83]
# truth		:  [930.528] [609.759]
#
# projection	:  [862.1] [604.17]
# truth		:  [880.547] [621.5]
#
# projection	:  [904.58] [483.43]
# truth		:  [957.167] [483.108]
#
# projection	:  [843.9] [483.45]
# truth		:  [889.321] [474.375]
#
# projection	:  [927.62] [548.3]
# truth		:  [974.738] [577.476]
#
# projection	:  [832.08] [564.18]
# truth		:  [859.959] [574.543]
#
# projection	:  [927.69] [496.79]
# truth		:  [930.528] [612.702]
#
# projection	:  [862.29] [604.35]
# truth		:  [883.512] [624.426]
#
# projection	:  [904.67] [483.52]
# truth		:  [957.17] [483.124]
#
# projection	:  [844.13] [483.49]
# truth		:  [886.41] [471.47]
#
# projection	:  [927.99] [548.21]
# truth		:  [974.718] [577.488]
#
# projection	:  [832.23] [564.17]
# truth		:  [859.812] [574.498]
#
# projection	:  [927.78] [496.73]
# truth		:  [927.646] [618.548]
#
# projection	:  [862.44] [604.3]
# truth		:  [883.481] [624.52]
#
# projection	:  [904.97] [483.33]
# truth		:  [957.15] [483.111]
#
# projection	:  [844.35] [483.41]
# truth		:  [883.553] [471.46]
#
# projection	:  [928.71] [547.56]
# truth		:  [974.711] [577.482]
#
# projection	:  [832.43] [564.14]
# truth		:  [857.034] [574.481]
#
# projection	:  [928.42] [496.45]
# truth		:  [930.513] [612.688]
#
# projection	:  [862.68] [604.34]
# truth		:  [883.519] [621.585]
#
# projection	:  [905.14] [483.65]
# truth		:  [957.181] [483.109]
#
# projection	:  [844.87] [483.45]
# truth		:  [883.38] [474.325]
#
# projection	:  [928.95] [547.74]
# truth		:  [974.718] [577.504]
#
# projection	:  [832.64] [563.95]
# truth		:  [857.003] [574.521]
#
# projection	:  [929.17] [496.34]
# truth		:  [927.662] [609.803]
#
# projection	:  [863.02] [604.49]
# truth		:  [886.424] [612.684]
#
# projection	:  [905.67] [483.72]
# truth		:  [957.136] [483.079]
#
# projection	:  [845.43] [483.36]
# truth		:  [880.566] [474.314]
#
# projection	:  [929.95] [547.49]
# truth		:  [974.733] [577.514]
#
# projection	:  [832.97] [563.67]
# truth		:  [856.94] [574.497]
#
# projection	:  [931.21] [496.14]
# truth		:  [927.638] [606.786]
#
# projection	:  [863.4] [604.64]
# truth		:  [892.306] [603.95]
#
# projection	:  [906.44] [483.79]
# truth		:  [957.103] [483.097]
#
# projection	:  [846.16] [483.04]
# truth		:  [880.484] [474.338]
#
# projection	:  [931.23] [547.16]
# truth		:  [974.712] [577.533]
#
# projection	:  [833.56] [563.39]
# truth		:  [856.949] [574.459]
#
# projection	:  [933.76] [495.22]
# truth		:  [924.707] [606.761]
#
# projection	:  [863.99] [604.79]
# truth		:  [892.302] [603.921]
#
# projection	:  [907.44] [483.63]
# truth		:  [957.005] [483.087]
#
# projection	:  [847.22] [482.8]
# truth		:  [880.43] [474.384]
#
# projection	:  [932.45] [547.12]
# truth		:  [974.708] [577.514]
#
# projection	:  [834.23] [562.84]
# truth		:  [856.895] [574.406]
#
# projection	:  [936.5] [495.08]
# truth		:  [927.575] [603.858]
#
# projection	:  [864.57] [604.65]
# truth		:  [889.338] [601.044]
#
# projection	:  [908.42] [483.72]
# truth		:  [954.12] [483.108]
#
# projection	:  [848.28] [482.37]
# truth		:  [877.473] [477.277]
#
# projection	:  [933.56] [547.82]
# truth		:  [974.622] [577.515]
#
# projection	:  [835.02] [562.28]
# truth		:  [856.855] [574.431]
#
# projection	:  [939.37] [495.05]
# truth		:  [927.603] [603.814]
#
# projection	:  [865.33] [604.39]
# truth		:  [889.367] [600.957]
#
# projection	:  [909.56] [484.06]
# truth		:  [954.061] [483.111]
#
# projection	:  [849.4] [482.]
# truth		:  [874.61] [477.274]
#
# projection	:  [934.98] [547.7]
# truth		:  [971.792] [577.519]
#
# projection	:  [835.87] [561.74]
# truth		:  [854.043] [574.389]
#
# projection	:  [942.5] [495.45]
# truth		:  [927.556] [601.036]
#
# projection	:  [866.] [604.18]
# truth		:  [889.351] [600.952]
#
# projection	:  [910.69] [484.07]
# truth		:  [951.24] [483.16]
#
# projection	:  [850.76] [481.84]
# truth		:  [868.749] [477.272]
#
# projection	:  [936.28] [547.98]
# truth		:  [965.924] [580.332]
#
# projection	:  [836.73] [561.17]
# truth		:  [854.084] [577.262]
#
# projection	:  [945.8] [496.07]
# truth		:  [924.656] [601.011]
#
# projection	:  [866.8] [604.08]
# truth		:  [892.342] [598.031]
#
# projection	:  [911.61] [484.51]
# truth		:  [951.091] [483.109]
#
# projection	:  [852.12] [481.5]
# truth		:  [862.978] [477.311]
#
# projection	:  [937.84] [547.89]
# truth		:  [965.893] [580.289]
#
# projection	:  [837.61] [560.56]
# truth		:  [853.97] [577.41]
#
# projection	:  [949.03] [496.94]
# truth		:  [927.581] [601.048]
#
# projection	:  [867.51] [604.05]
# truth		:  [892.277] [600.871]
#
# projection	:  [913.16] [484.36]
# truth		:  [948.237] [483.104]
#
# projection	:  [853.37] [481.18]
# truth		:  [862.913] [477.29]
#
# projection	:  [939.22] [548.09]
# truth		:  [960.049] [577.479]
#
# projection	:  [838.55] [559.98]
# truth		:  [853.932] [577.314]
#
# projection	:  [951.84] [497.89]
# truth		:  [927.575] [601.031]
#
# projection	:  [868.22] [604.03]
# truth		:  [886.454] [600.875]
#
# projection	:  [914.17] [484.77]
# truth		:  [945.234] [483.139]
#
# projection	:  [854.91] [481.08]
# truth		:  [859.964] [480.091]
#
# projection	:  [940.56] [548.34]
# truth		:  [954.239] [580.327]
#
# projection	:  [839.5] [559.46]
# truth		:  [845.174] [574.518]
#
# projection	:  [954.17] [498.56]
# truth		:  [921.789] [603.826]
#
# projection	:  [868.91] [604.01]
# truth		:  [883.502] [598.052]
#
# projection	:  [915.55] [484.8]
# truth		:  [936.445] [483.115]
#
# projection	:  [856.12] [480.81]
# truth		:  [859.839] [480.218]
#
# projection	:  [941.61] [548.87]
# truth		:  [954.089] [580.401]
#
# projection	:  [840.32] [558.91]
# truth		:  [839.365] [574.525]
#
# projection	:  [955.02] [498.62]
# truth		:  [921.788] [606.819]
#
# projection	:  [869.6] [603.88]
# truth		:  [883.496] [600.905]
#
# projection	:  [916.39] [484.98]
# truth		:  [930.648] [483.206]
#
# projection	:  [856.97] [480.58]
# truth		:  [857.013] [480.246]
#
# projection	:  [942.38] [549.23]
# truth		:  [951.133] [580.391]
#
# projection	:  [840.99] [558.51]
# truth		:  [836.47] [574.464]
#
# projection	:  [955.3] [498.43]
# truth		:  [921.673] [603.873]
#
# projection	:  [870.24] [603.75]
# truth		:  [886.386] [600.831]
#
# projection	:  [916.99] [485.12]
# truth		:  [930.452] [483.297]
#
# projection	:  [857.6] [480.33]
# truth		:  [856.842] [480.277]
#
# projection	:  [942.56] [549.75]
# truth		:  [945.253] [583.23]
#
# projection	:  [841.47] [558.2]
# truth		:  [836.404] [574.407]
#
# projection	:  [955.6] [498.57]
# truth		:  [912.902] [606.79]
#
# projection	:  [870.56] [603.44]
# truth		:  [886.38] [598.008]
#
# projection	:  [917.49] [485.72]
# truth		:  [927.554] [483.365]
#
# projection	:  [858.09] [480.14]
# truth		:  [853.922] [480.281]
#
# projection	:  [942.62] [551.06]
# truth		:  [942.29] [583.256]
#
# projection	:  [841.66] [557.68]
# truth		:  [833.558] [574.308]
#
# projection	:  [955.4] [500.81]
# truth		:  [909.926] [606.809]
#
# projection	:  [870.61] [603.29]
# truth		:  [880.531] [600.896]
#
# projection	:  [917.67] [487.44]
# truth		:  [912.968] [483.237]
#
# projection	:  [858.56] [479.75]
# truth		:  [845.231] [480.268]
#
# projection	:  [941.93] [554.27]
# truth		:  [930.539] [583.322]
#
# projection	:  [841.63] [557.01]
# truth		:  [833.461] [565.653]
#
# projection	:  [955.37] [504.82]
# truth		:  [904.089] [595.077]
#
# projection	:  [870.29] [603.16]
# truth		:  [862.832] [597.913]
#
# projection	:  [918.17] [489.32]
# truth		:  [909.954] [483.213]
#
# projection	:  [859.14] [479.17]
# truth		:  [842.324] [480.279]
#
# projection	:  [941.07] [558.37]
# truth		:  [927.7] [580.431]
#
# projection	:  [841.38] [555.86]
# truth		:  [833.344] [559.763]
#
# projection	:  [955.5] [509.25]
# truth		:  [904.041] [595.054]
#
# projection	:  [869.72] [602.92]
# truth		:  [859.861] [592.093]
#
# projection	:  [918.53] [491.35]
# truth		:  [907.012] [483.192]
#
# projection	:  [859.76] [478.65]
# truth		:  [839.371] [480.264]
#
# projection	:  [940.26] [561.27]
# truth		:  [927.47] [580.276]
#
# projection	:  [840.89] [554.43]
# truth		:  [833.301] [556.884]
#
# projection	:  [955.35] [513.98]
# truth		:  [903.984] [589.198]
#
# projection	:  [868.87] [602.56]
# truth		:  [862.852] [597.946]
#
# projection	:  [918.68] [493.51]
# truth		:  [904.173] [483.16]
#
# projection	:  [860.19] [478.3]
# truth		:  [836.498] [480.28]
#
# projection	:  [939.22] [565.13]
# truth		:  [921.776] [580.263]
#
# projection	:  [840.35] [553.2]
# truth		:  [827.584] [562.683]
#
# projection	:  [954.89] [519.47]
# truth		:  [904.008] [577.419]
#
# projection	:  [867.92] [602.29]
# truth		:  [862.865] [597.944]
#
# projection	:  [918.81] [495.81]
# truth		:  [903.981] [483.19]
#
# projection	:  [860.63] [478.08]
# truth		:  [836.33] [480.232]
#
# projection	:  [938.] [568.74]
# truth		:  [921.713] [580.272]
#
# projection	:  [839.76] [552.06]
# truth		:  [824.628] [556.875]
#
# projection	:  [954.77] [524.94]
# truth		:  [904.177] [571.502]
#
# projection	:  [866.97] [602.2]
# truth		:  [859.937] [597.965]
#
# projection	:  [918.82] [498.33]
# truth		:  [898.141] [483.079]
#
# projection	:  [861.09] [478.01]
# truth		:  [833.451] [480.21]
#
# projection	:  [936.75] [572.46]
# truth		:  [912.96] [577.379]
#
# projection	:  [839.24] [551.03]
# truth		:  [815.88] [556.865]
#
# projection	:  [954.58] [530.83]
# truth		:  [927.516] [559.772]
#
# projection	:  [865.96] [602.31]
# truth		:  [856.957] [595.055]
#
# projection	:  [918.96] [500.81]
# truth		:  [889.438] [480.332]
#
# projection	:  [861.54] [477.83]
# truth		:  [833.404] [480.174]
#
# projection	:  [935.61] [576.15]
# truth		:  [912.936] [574.407]
#
# projection	:  [838.74] [549.91]
# truth		:  [815.8] [556.773]
#
# projection	:  [954.45] [536.57]
# truth		:  [930.539] [553.926]
#
# projection	:  [864.98] [602.34]
# truth		:  [859.878] [586.198]
#
# projection	:  [919.1] [503.67]
# truth		:  [886.445] [480.276]
#
# projection	:  [862.24] [477.83]
# truth		:  [833.295] [480.138]
#
# projection	:  [934.13] [579.98]
# truth		:  [912.903] [574.292]
#
# projection	:  [838.33] [548.75]
# truth		:  [812.9] [556.882]
#
# projection	:  [954.39] [542.68]
# truth		:  [930.71] [550.779]
#
# projection	:  [864.01] [602.15]
# truth		:  [859.925] [577.332]
#
# projection	:  [919.4] [506.16]
# truth		:  [883.61] [480.303]
#
# projection	:  [863.05] [477.85]
# truth		:  [830.458] [480.144]
#
# projection	:  [932.79] [583.85]
# truth		:  [912.922] [571.44]
#
# projection	:  [837.99] [547.49]
# truth		:  [812.756] [556.838]
#
# projection	:  [954.15] [548.86]
# truth		:  [933.489] [539.079]
#
# projection	:  [863.15] [601.93]
# truth		:  [857.054] [571.456]
#
# projection	:  [919.73] [508.57]
# truth		:  [883.528] [480.249]
#
# projection	:  [863.92] [477.96]
# truth		:  [827.549] [480.078]
#
# projection	:  [931.56] [587.35]
# truth		:  [915.808] [568.529]
#
# projection	:  [837.83] [546.38]
# truth		:  [810.] [556.749]
#
# projection	:  [953.94] [553.6]
# truth		:  [933.578] [533.295]
#
# projection	:  [862.47] [601.67]
# truth		:  [854.033] [574.372]
#
# projection	:  [920.36] [509.67]
# truth		:  [883.434] [480.252]
#
# projection	:  [864.47] [478.08]
# truth		:  [827.517] [480.133]
#
# projection	:  [930.95] [589.34]
# truth		:  [915.864] [562.681]
#
# projection	:  [837.73] [545.65]
# truth		:  [809.97] [556.799]
#
# projection	:  [953.76] [556.67]
# truth		:  [936.426] [530.198]
#
# projection	:  [861.89] [601.63]
# truth		:  [853.961] [577.335]
#
# projection	:  [920.29] [510.5]
# truth		:  [883.367] [480.216]
#
# projection	:  [864.66] [478.11]
# truth		:  [824.615] [480.158]
#
# projection	:  [930.93] [589.97]
# truth		:  [915.859] [559.757]
#
# projection	:  [837.66] [545.28]
# truth		:  [809.967] [556.842]
#
# projection	:  [953.97] [557.59]
# truth		:  [933.581] [527.315]
#
# projection	:  [861.55] [601.65]
# truth		:  [851.101] [577.442]
#
# projection	:  [920.35] [510.84]
# truth		:  [880.609] [480.245]
#
# projection	:  [864.71] [478.19]
# truth		:  [824.605] [480.197]
#
# projection	:  [931.05] [590.09]
# truth		:  [921.688] [562.615]
#
# projection	:  [837.67] [545.31]
# truth		:  [810.009] [559.724]
#
# projection	:  [954.07] [557.51]
# truth		:  [933.605] [521.471]
#
# projection	:  [861.4] [601.59]
# truth		:  [853.972] [580.306]
#
# projection	:  [920.42] [510.46]
# truth		:  [880.581] [480.296]
#
# projection	:  [864.6] [478.3]
# truth		:  [824.648] [480.207]
#
# projection	:  [931.11] [589.9]
# truth		:  [921.755] [556.874]
#
# projection	:  [837.69] [545.56]
# truth		:  [812.752] [562.625]
#
# projection	:  [953.8] [557.53]
# truth		:  [939.407] [515.567]
#
# projection	:  [861.51] [601.66]
# truth		:  [845.209] [592.073]
#
# projection	:  [920.25] [510.35]
# truth		:  [880.538] [480.368]
#
# projection	:  [864.39] [478.52]
# truth		:  [827.493] [480.21]
#
# projection	:  [930.97] [589.65]
# truth		:  [924.613] [556.73]
#
# projection	:  [837.63] [545.97]
# truth		:  [812.731] [562.66]
#
# projection	:  [952.79] [557.02]
# truth		:  [945.303] [512.686]
#
# projection	:  [861.69] [602.02]
# truth		:  [839.376] [597.881]
#
# projection	:  [919.69] [510.65]
# truth		:  [880.522] [480.352]
#
# projection	:  [863.95] [478.68]
# truth		:  [827.537] [480.159]
#
# projection	:  [930.12] [590.04]
# truth		:  [927.544] [553.896]
#
# projection	:  [837.43] [546.43]
# truth		:  [812.808] [559.779]
#
# projection	:  [950.9] [556.96]
# truth		:  [948.12] [509.702]
#
# projection	:  [861.61] [602.17]
# truth		:  [836.508] [598.007]
#
# projection	:  [919.34] [510.29]
# truth		:  [880.54] [480.374]
#
# projection	:  [863.1] [478.76]
# truth		:  [827.549] [480.168]
#
# projection	:  [928.39] [590.75]
# truth		:  [927.622] [550.949]
#
# projection	:  [836.77] [546.7]
# truth		:  [812.769] [562.64]
#
# projection	:  [948.34] [556.98]
# truth		:  [942.324] [503.871]
#
# projection	:  [860.91] [601.96]
# truth		:  [836.458] [597.957]
#
# projection	:  [917.99] [510.92]
# truth		:  [880.584] [480.369]
#
# projection	:  [861.91] [478.85]
# truth		:  [827.587] [480.22]
#
# projection	:  [926.56] [591.54]
# truth		:  [927.735] [550.886]
#
# projection	:  [835.61] [546.77]
# truth		:  [812.822] [559.692]
#
# projection	:  [945.39] [556.53]
# truth		:  [948.192] [503.844]
#
# projection	:  [859.53] [601.88]
# truth		:  [839.334] [597.931]
#
# projection	:  [916.67] [511.54]
# truth		:  [880.609] [480.378]
#
# projection	:  [860.49] [478.99]
# truth		:  [827.539] [480.279]
#
# projection	:  [924.65] [591.92]
# truth		:  [930.45] [550.792]
#
# projection	:  [834.21] [546.85]
# truth		:  [812.931] [562.67]
#
# projection	:  [942.23] [557.03]
# truth		:  [951.104] [503.685]
#
# projection	:  [857.92] [602.16]
# truth		:  [845.208] [600.915]
#
# projection	:  [915.36] [511.56]
# truth		:  [880.635] [483.053]
#
# projection	:  [858.95] [479.17]
# truth		:  [830.39] [480.287]
#
# projection	:  [922.71] [592.2]
# truth		:  [930.585] [550.75]
#
# projection	:  [832.81] [547.12]
# truth		:  [812.932] [568.53]
#
# projection	:  [938.94] [557.35]
# truth		:  [954.025] [503.719]
#
# projection	:  [856.17] [602.37]
# truth		:  [848.131] [603.857]
#
# projection	:  [913.96] [511.67]
# truth		:  [883.412] [483.076]
#
# projection	:  [857.35] [479.45]
# truth		:  [830.443] [480.331]
#
# projection	:  [920.74] [592.59]
# truth		:  [930.717] [550.855]
#
# projection	:  [831.37] [547.53]
# truth		:  [812.898] [571.405]
#
# projection	:  [935.46] [557.46]
# truth		:  [954.095] [503.708]
#
# projection	:  [854.55] [602.64]
# truth		:  [845.277] [603.837]
#
# projection	:  [912.51] [511.38]
# truth		:  [883.491] [483.069]
#
# projection	:  [855.7] [479.79]
# truth		:  [830.503] [480.321]
#
# projection	:  [918.93] [592.59]
# truth		:  [930.734] [550.861]
#
# projection	:  [830.05] [548.21]
# truth		:  [812.866] [571.376]
#
# projection	:  [932.47] [556.85]
# truth		:  [954.103] [503.766]
#
# projection	:  [853.34] [603.34]
# truth		:  [839.437] [600.939]
#
# projection	:  [911.21] [510.87]
# truth		:  [883.588] [483.105]
#
# projection	:  [854.01] [480.02]
# truth		:  [833.32] [480.336]
#
# projection	:  [917.19] [592.31]
# truth		:  [933.516] [550.935]
#
# projection	:  [828.72] [548.82]
# truth		:  [812.855] [568.583]
#
# projection	:  [929.71] [556.8]
# truth		:  [954.132] [506.665]
#
# projection	:  [852.05] [603.68]
# truth		:  [839.399] [600.862]
#
# projection	:  [909.94] [510.87]
# truth		:  [883.584] [483.131]
#
# projection	:  [852.53] [480.27]
# truth		:  [833.398] [480.338]
#
# projection	:  [915.58] [592.39]
# truth		:  [933.548] [553.707]
#
# projection	:  [827.46] [549.23]
# truth		:  [812.897] [571.472]
#
# projection	:  [926.91] [557.81]
# truth		:  [954.048] [506.668]
#
# projection	:  [850.64] [603.92]
# truth		:  [845.227] [597.975]
#
# projection	:  [908.91] [510.94]
# truth		:  [883.599] [483.133]
#
# projection	:  [851.4] [480.43]
# truth		:  [833.435] [480.374]
#
# projection	:  [914.5] [592.38]
# truth		:  [933.533] [553.713]
#
# projection	:  [826.48] [549.54]
# truth		:  [812.953] [571.466]
#
# projection	:  [925.93] [558.43]
# truth		:  [953.994] [506.706]
#
# projection	:  [849.42] [604.14]
# truth		:  [842.314] [600.871]
#
# projection	:  [908.33] [510.5]
# truth		:  [886.425] [483.157]
#
# projection	:  [850.62] [480.55]
# truth		:  [833.472] [480.366]
#
# projection	:  [914.29] [592.09]
# truth		:  [933.584] [553.816]
#
# projection	:  [825.81] [549.7]
# truth		:  [812.982] [571.414]
#
# projection	:  [925.79] [558.55]
# truth		:  [954.] [506.771]
#
# projection	:  [848.66] [604.35]
# truth		:  [842.333] [597.995]
#
# projection	:  [907.95] [510.06]
# truth		:  [886.449] [483.153]
#
# projection	:  [850.19] [480.63]
# truth		:  [833.493] [480.368]
#
# projection	:  [914.26] [592.27]
# truth		:  [933.628] [553.79]
#
# projection	:  [825.54] [550.06]
# truth		:  [812.993] [571.507]
#
# projection	:  [926.27] [556.33]
# truth		:  [953.999] [506.791]
#
# projection	:  [848.48] [604.42]
# truth		:  [845.244] [598.036]
#
# projection	:  [907.63] [508.8]
# truth		:  [886.494] [483.161]
#
# projection	:  [849.68] [480.62]
# truth		:  [833.5] [480.382]
#
# projection	:  [914.72] [590.05]
# truth		:  [936.431] [553.864]
#
# projection	:  [825.5] [550.63]
# truth		:  [812.98] [571.486]
#
# projection	:  [925.75] [554.29]
# truth		:  [954.014] [506.776]
#
# projection	:  [848.95] [604.31]
# truth		:  [848.151] [598.006]
#
# projection	:  [907.65] [506.26]
# truth		:  [886.507] [483.161]
#
# projection	:  [848.87] [480.53]
# truth		:  [833.541] [480.384]
#
# projection	:  [915.24] [587.22]
# truth		:  [936.483] [553.895]
#
# projection	:  [825.49] [551.47]
# truth		:  [812.977] [571.456]
#
# projection	:  [925.72] [549.18]
# truth		:  [954.032] [506.785]
#
# projection	:  [849.53] [603.98]
# truth		:  [845.205] [598.002]
#
# projection	:  [906.99] [503.57]
# truth		:  [886.543] [483.177]
#
# projection	:  [847.93] [480.52]
# truth		:  [836.268] [480.373]
#
# projection	:  [916.76] [582.87]
# truth		:  [936.488] [553.858]
#
# projection	:  [825.67] [552.68]
# truth		:  [813.009] [571.406]
#
# projection	:  [925.45] [542.09]
# truth		:  [954.024] [506.78]
#
# projection	:  [849.9] [603.62]
# truth		:  [848.142] [597.968]
#
# projection	:  [906.7] [499.94]
# truth		:  [889.327] [483.191]
#
# projection	:  [846.95] [480.75]
# truth		:  [836.286] [480.367]
#
# projection	:  [918.34] [577.63]
# truth		:  [936.51] [553.852]
#
# projection	:  [825.77] [553.95]
# truth		:  [815.744] [571.404]
#
# projection	:  [926.01] [531.78]
# truth		:  [954.013] [506.787]
#
# projection	:  [850.42] [603.66]
# truth		:  [848.205] [597.98]
#
# projection	:  [906.25] [496.31]
# truth		:  [889.359] [483.183]
#
# projection	:  [846.] [481.18]
# truth		:  [836.3] [480.382]
#
# projection	:  [919.77] [571.45]
# truth		:  [936.516] [553.813]
#
# projection	:  [825.99] [555.45]
# truth		:  [815.779] [571.386]
#
# projection	:  [926.39] [521.74]
# truth		:  [954.041] [506.733]
#
# projection	:  [850.83] [603.79]
# truth		:  [848.213] [598.012]
#
# projection	:  [905.76] [492.8]
# truth		:  [886.54] [483.149]
#
# projection	:  [845.14] [481.47]
# truth		:  [836.33] [480.378]
#
# projection	:  [921.04] [565.54]
# truth		:  [939.344] [553.779]
#
# projection	:  [826.31] [556.72]
# truth		:  [815.787] [568.596]
#
# projection	:  [926.54] [513.21]
# truth		:  [954.083] [506.725]
#
# projection	:  [851.2] [603.82]
# truth		:  [848.171] [598.016]
#
# projection	:  [905.19] [490.14]
# truth		:  [889.333] [483.169]
#
# projection	:  [844.46] [481.87]
# truth		:  [836.332] [480.383]
#
# projection	:  [922.22] [560.19]
# truth		:  [939.365] [553.792]
#
# projection	:  [826.67] [558.03]
# truth		:  [815.786] [571.368]
#
# projection	:  [926.48] [505.63]
# truth		:  [954.134] [506.723]
#
# projection	:  [851.55] [603.57]
# truth		:  [851.145] [597.963]
#
# projection	:  [904.71] [488.16]
# truth		:  [889.36] [483.186]
#
# projection	:  [843.88] [482.49]
# truth		:  [836.336] [480.378]
#
# projection	:  [923.03] [555.88]
# truth		:  [939.393] [553.789]
#
# projection	:  [827.17] [559.47]
# truth		:  [815.769] [568.592]
#
# projection	:  [926.26] [500.01]
# truth		:  [954.143] [506.703]
#
# projection	:  [851.87] [603.37]
# truth		:  [851.125] [597.929]
#
# projection	:  [904.64] [487.07]
# truth		:  [889.372] [483.193]
#
# projection	:  [843.44] [482.94]
# truth		:  [836.346] [480.379]
#
# projection	:  [923.43] [554.1]
# truth		:  [939.358] [553.823]
#
# projection	:  [827.57] [560.52]
# truth		:  [815.738] [568.56]
#
# projection	:  [926.04] [498.4]
# truth		:  [954.158] [506.717]
#
# projection	:  [852.13] [603.02]
# truth		:  [851.106] [598.002]
#
# projection	:  [904.6] [486.61]
# truth		:  [889.387] [483.193]
#
# projection	:  [843.2] [483.]
# truth		:  [836.349] [480.378]
#
# projection	:  [923.5] [553.78]
# truth		:  [939.389] [553.815]
#
# projection	:  [827.79] [560.95]
# truth		:  [815.763] [568.559]
#
# projection	:  [925.63] [499.32]
# truth		:  [954.181] [506.778]
#
# projection	:  [852.31] [602.67]
# truth		:  [851.055] [598.002]
#
# projection	:  [904.63] [486.54]
# truth		:  [889.384] [483.208]
#
# projection	:  [843.16] [483.09]
# truth		:  [836.378] [480.378]
#
# projection	:  [923.42] [553.8]
# truth		:  [939.449] [553.818]
#
# projection	:  [827.83] [561.1]
# truth		:  [815.778] [571.366]
#
# projection	:  [925.58] [499.55]
# truth		:  [954.208] [506.712]
#
# projection	:  [852.42] [602.53]
# truth		:  [853.98] [598.019]
#
# projection	:  [904.64] [486.56]
# truth		:  [889.402] [483.223]
#
# projection	:  [843.27] [483.12]
# truth		:  [836.408] [480.365]
#
# projection	:  [923.51] [553.33]
# truth		:  [939.451] [553.852]
#
# projection	:  [827.89] [561.16]
# truth		:  [815.833] [568.528]
#
# projection	:  [926.06] [498.3]
# truth		:  [954.207] [506.753]
#
# projection	:  [852.39] [602.36]
# truth		:  [851.139] [597.996]
#
# projection	:  [904.57] [486.54]
# truth		:  [889.442] [483.189]
#
# projection	:  [843.26] [483.18]
# truth		:  [836.436] [480.384]
#
# projection	:  [923.61] [553.34]
# truth		:  [942.296] [553.825]
#
# projection	:  [827.85] [561.18]
# truth		:  [815.869] [568.524]
#
# projection	:  [926.32] [498.1]
# truth		:  [957.046] [506.659]
#
# projection	:  [852.44] [601.88]
# truth		:  [851.154] [600.906]
#
# projection	:  [904.32] [486.36]
# truth		:  [892.291] [483.222]
#
# projection	:  [842.9] [483.26]
# truth		:  [836.453] [483.058]
#
# projection	:  [923.81] [552.89]
# truth		:  [942.337] [553.733]
#
# projection	:  [827.9] [561.61]
# truth		:  [818.697] [568.537]
#
# projection	:  [926.26] [498.27]
# truth		:  [957.04] [503.838]
#
# projection	:  [852.71] [600.97]
# truth		:  [853.993] [597.99]
#
# projection	:  [903.73] [486.01]
# truth		:  [892.279] [483.223]
#
# projection	:  [842.38] [483.86]
# truth		:  [836.474] [483.08]
# projection	:  [923.48] [553.07]
# truth		:  [942.322] [553.877]
#
# projection	:  [827.86] [562.56]
# truth		:  [818.713] [568.52]
#
# projection	:  [925.76] [498.18]
# truth		:  [959.979] [506.644]
#
# projection	:  [853.2] [600.24]
# truth		:  [856.89] [598.024]
#
# projection	:  [902.66] [485.51]
# truth		:  [892.279] [483.192]
#
# projection	:  [841.27] [484.72]
# truth		:  [836.487] [483.075]
#
# projection	:  [922.93] [553.47]
# truth		:  [942.354] [553.845]
#
# projection	:  [827.67] [564.01]
# truth		:  [818.755] [568.487]
#
# projection	:  [924.8] [498.83]
# truth		:  [962.988] [503.911]
#
# projection	:  [853.63] [599.62]
# truth		:  [856.914] [597.95]
#
# projection	:  [901.11] [484.74]
# truth		:  [892.303] [483.206]
#
# projection	:  [839.68] [485.81]
# truth		:  [836.51] [483.072]
#
# projection	:  [921.81] [554.46]
# truth		:  [945.219] [553.832]
#
# projection	:  [827.2] [565.75]
# truth		:  [821.619] [568.528]
#
# projection	:  [922.32] [502.99]
# truth		:  [965.839] [506.78]
#
# projection	:  [854.28] [598.57]
# truth		:  [859.828] [597.978]
#
# projection	:  [898.43] [484.71]
# truth		:  [892.346] [483.201]
#
# projection	:  [837.55] [487.]
# truth		:  [836.53] [483.062]
#
# projection	:  [919.89] [556.1]
# truth		:  [945.251] [553.788]
#
# projection	:  [826.49] [567.69]
# truth		:  [824.566] [565.604]
#
# projection	:  [920.21] [506.5]
# truth		:  [965.88] [506.698]
#
# projection	:  [854.98] [596.93]
# truth		:  [859.84] [597.991]
#
# projection	:  [895.2] [485.94]
# truth		:  [895.298] [483.216]
#
# projection	:  [835.21] [488.17]
# truth		:  [839.277] [483.073]
#
# projection	:  [916.9] [558.5]
# truth		:  [945.309] [553.829]
#
# projection	:  [825.59] [569.49]
# truth		:  [824.568] [568.473]
#
# projection	:  [916.63] [512.2]
# truth		:  [968.849] [506.69]
#
# projection	:  [855.63] [594.3]
# truth		:  [857.043] [594.979]
#
# projection	:  [892.35] [485.67]
# truth		:  [895.253] [483.201]
#
# projection	:  [832.82] [489.47]
# truth		:  [839.338] [483.09]
#
# projection	:  [912.94] [561.07]
# truth		:  [948.2] [553.801]
#
# projection	:  [824.59] [571.41]
# truth		:  [824.588] [568.573]
#
# projection	:  [911.96] [520.94]
# truth		:  [968.839] [506.682]
#
# projection	:  [856.25] [591.05]
# truth		:  [857.054] [595.046]
#
# projection	:  [889.23] [485.79]
# truth		:  [898.123] [483.228]
#
# projection	:  [830.98] [490.66]
# truth		:  [839.374] [483.105]
#
# projection	:  [909.07] [561.62]
# truth		:  [948.277] [553.781]
#
# projection	:  [823.67] [573.09]
# truth		:  [824.614] [568.52]
#
# projection	:  [906.68] [531.81]
# truth		:  [971.746] [503.867]
#
# projection	:  [857.04] [587.67]
# truth		:  [859.852] [597.954]
#
# projection	:  [887.02] [485.26]
# truth		:  [898.216] [483.27]
#
# projection	:  [829.77] [491.73]
# truth		:  [839.404] [483.113]
#
# projection	:  [904.79] [562.32]
# truth		:  [951.038] [553.797]
#
# projection	:  [823.23] [574.4]
# truth		:  [827.496] [568.485]
#
# projection	:  [900.57] [544.8]
# truth		:  [974.592] [503.799]
#
# projection	:  [858.35] [584.43]
# truth		:  [857.003] [597.97]
#
# projection	:  [885.54] [484.71]
# truth		:  [901.028] [483.297]
#
# projection	:  [829.34] [492.56]
# truth		:  [839.441] [483.11]
#
# projection	:  [902.03] [562.33]
# truth		:  [951.032] [553.744]
#
# projection	:  [823.48] [575.21]
# truth		:  [827.579] [565.584]
#
# projection	:  [896.11] [554.89]
# truth		:  [974.745] [506.752]
#
# projection	:  [859.72] [581.28]
# truth		:  [856.997] [597.889]

# %%
print(stdev(dist_list))
# Out:
# 25.811490649144375
